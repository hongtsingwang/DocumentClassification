# %% [markdown]
# <a href="https://colab.research.google.com/github/hongtsingwang/DocumentClassification/blob/master/TensorflowWord2VecImplentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector

# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
  os.makedirs(FLAGS.log_dir)

# %%
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data


vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# Out:
# Data size 17005207

# %%
def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

# %%
print(generate_batch(batch_size=8, num_skips=2, skip_window=1))
# Out:
# (array([3081, 3081,   12,   12,    6,    6,  195,  195], dtype=int32), array([[5234],
#        [  12],
#        [   6],
#        [3081],
#        [  12],
#        [ 195],
#        [   6],
#        [   2]], dtype=int32))

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 2 of -> 195 term
# 2 of -> 3134 abuse
# 3134 abuse -> 2 of
# 3134 abuse -> 46 first
# 46 first -> 3134 abuse
# 46 first -> 59 used
# 59 used -> 46 first
# 59 used -> 156 against

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  

  # Create a saver.
  saver = tf.train.Saver()

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
    # Feed metadata variable to session for visualizing the graph in TensorBoard.
    _, summary, loss_val = session.run(
        [optimizer, merged, loss],
        feed_dict=feed_dict,
        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  292.61553955078125
# Nearest to all: visibly, automatic, frequentist, station, physicists, rehearsing, syringe, custer,
# Nearest to united: adnan, kasparov, matilda, dih, honeybee, synapses, scanner, incidentally,
# Nearest to used: cris, eccentric, wren, labeling, lak, marcel, ghaznavid, knighthood,
# Nearest to however: revised, affonso, tangerine, geralt, ammonites, ansar, unworkable, saban,
# Nearest to their: recur, pasolini, undersea, solace, wapping, malaysians, abwehr, gazelle,
# Nearest to not: tutoring, works, bequeathed, hijacked, muppet, lupus, millimetres, poem,
# Nearest to some: unprotected, libro, black, dopant, vitro, kwajalein, tahoe, slammed,
# Nearest to th: connery, deck, persephone, mutton, ramakrishna, unwitting, apcs, courtship,
# Nearest to about: valery, woollen, kabaddi, deepening, quagga, postpone, francesco, simulations,
# Nearest to this: chili, armenian, wraps, astaire, monoxide, konar, rubin, everett,
# Nearest to states: sebastian, cle, waited, centralization, dynasty, gareth, lamarck, papeete,
# Nearest to five: inexpensively, bureaucratic, simplest, foliage, bihari, nasty, despot, avalon,
# Nearest to people: queues, alabama, sci, supplanting, majapahit, accents, phrygian, biotech,
# Nearest to by: patriarchy, pla, varanus, divorces, appomattox, playfair, purge, slept,
# Nearest to known: openings, vowed, yama, ain, elapsed, pe, exerted, deflation,
# Nearest to if: nasal, pectoral, denton, diels, lasted, folie, cockroaches, proactive,
# Average loss at step  2000 :  113.34118528461457
# Average loss at step  4000 :  52.80909983968735
# Average loss at step  6000 :  33.434655670642854
# Average loss at step  8000 :  23.443924503803252
# Average loss at step  10000 :  18.101369540691376
# Nearest to all: automatic, lymphoma, received, physicists, scholars, mathbf, instruments, pass,
# Nearest to united: kasparov, face, option, theological, ace, series, trauma, thanks,
# Nearest to used: pronounced, canaris, mhz, finalist, laura, mathbf, uat, proceeding,
# Nearest to however: revised, canaris, archie, cardinality, rs, values, mathbf, schools,
# Nearest to their: the, his, soroban, als, a, abwehr, yeast, wallace,
# Nearest to not: prior, phi, circuit, universals, works, ghostly, mathbf, poem,
# Nearest to some: the, appeared, unprotected, markov, yum, uke, robeson, black,
# Nearest to th: connery, lymphoma, deck, germany, nine, zero, decides, freedom,
# Nearest to about: molinari, kenya, archie, v, argued, woollen, resigned, UNK,
# Nearest to this: aq, the, his, a, armenian, agave, that, wiring,
# Nearest to states: sebastian, dynasty, canaris, the, paradox, democracy, promoted, co,
# Nearest to five: zero, nine, gland, four, lymphoma, one, six, mathbf,
# Nearest to people: alabama, caribbean, arabic, phi, demanded, phrygian, sci, driven,
# Nearest to by: and, is, in, at, of, UNK, with, milne,
# Nearest to known: openings, arranged, arrival, elapsed, situated, pe, refrigeration, needs,
# Nearest to if: nasal, archie, vowels, lasted, denton, corruption, canaris, tautologies,
# Average loss at step  12000 :  14.05377865242958
# Average loss at step  14000 :  11.654877599954606
# Average loss at step  16000 :  10.080041571259498
# Average loss at step  18000 :  8.453010112047195
# Average loss at step  20000 :  8.111120684981346
# Nearest to all: automatic, dasyprocta, lymphoma, instruments, received, scholars, anchor, visibly,
# Nearest to united: circ, kasparov, matilda, ace, face, hadith, theological, option,
# Nearest to used: agouti, pronounced, circ, laura, canaris, mathbf, mhz, finalist,
# Nearest to however: agouti, circ, trapezohedron, affonso, ammonites, canaris, archie, rs,
# Nearest to their: the, his, its, a, soroban, wallace, cistercian, als,
# Nearest to not: phi, to, it, prior, universals, circuit, works, also,
# Nearest to some: the, many, appeared, agouti, markov, dasyprocta, unprotected, yum,
# Nearest to th: connery, eight, six, deck, seven, five, akkad, robb,
# Nearest to about: dasyprocta, agouti, kenya, archie, six, molinari, v, resigned,
# Nearest to this: the, a, his, that, aq, it, agouti, dasyprocta,
# Nearest to states: sebastian, dasyprocta, acacia, agouti, canaris, centralization, dynasty, the,
# Nearest to five: nine, zero, six, eight, four, two, seven, agouti,
# Nearest to people: alabama, caribbean, sci, phi, arabic, demanded, slope, frequent,
# Nearest to by: in, dasyprocta, was, and, with, is, from, circ,
# Nearest to known: openings, pe, refrigeration, arranged, elapsed, arrival, linux, frying,
# Nearest to if: nasal, archie, dasyprocta, and, finite, lasted, vowels, under,
# Average loss at step  22000 :  7.166540306448937
# Average loss at step  24000 :  6.867475877165794
# Average loss at step  26000 :  6.808450974106789
# Average loss at step  28000 :  6.355732275247574
# Average loss at step  30000 :  5.9204254517555235
# Nearest to all: automatic, visibly, scholars, dasyprocta, custer, instruments, anchor, disk,
# Nearest to united: adnan, kasparov, circ, matilda, ace, face, hadith, of,
# Nearest to used: agouti, circ, pronounced, laura, canaris, mathbf, relied, found,
# Nearest to however: agouti, circ, trapezohedron, that, ammonites, canaris, archie, affonso,
# Nearest to their: the, his, its, a, wallace, cistercian, soroban, edges,
# Nearest to not: phi, it, also, prior, still, to, universals, poem,
# Nearest to some: many, the, appeared, markov, agouti, robeson, dasyprocta, its,
# Nearest to th: connery, six, deck, eight, nine, seven, akkad, apcs,
# Nearest to about: dasyprocta, six, archie, agouti, resigned, kenya, seven, nearest,
# Nearest to this: which, the, it, that, a, aq, his, agouti,
# Nearest to states: sebastian, dasyprocta, acacia, agouti, canaris, centralization, dynasty, ascorbic,
# Nearest to five: six, eight, four, zero, nine, seven, three, two,
# Nearest to people: alabama, sci, caribbean, phi, arabic, slope, shooter, handler,
# Nearest to by: with, in, was, from, and, dasyprocta, for, circ,
# Nearest to known: openings, pe, refrigeration, frying, linux, agouti, elapsed, arranged,
# Nearest to if: nasal, but, canova, archie, finite, akh, dasyprocta, under,
# Average loss at step  32000 :  6.029435629010201
# Average loss at step  34000 :  5.707210385560989
# Average loss at step  36000 :  5.776634071230888
# Average loss at step  38000 :  5.519978146076203
# Average loss at step  40000 :  5.256643595814705
# Nearest to all: automatic, dasyprocta, visibly, spotters, circ, scholars, anchor, custer,
# Nearest to united: adnan, circ, kasparov, of, matilda, ace, hadith, face,
# Nearest to used: agouti, circ, found, laura, pronounced, trusts, four, relied,
# Nearest to however: agouti, that, circ, but, when, trapezohedron, geralt, which,
# Nearest to their: his, its, the, a, predicates, her, wallace, cistercian,
# Nearest to not: still, phi, it, also, prior, poem, to, universals,
# Nearest to some: many, these, the, robeson, appeared, agouti, dasyprocta, its,
# Nearest to th: six, eight, seven, connery, nine, zero, deck, four,
# Nearest to about: six, dasyprocta, seven, archie, agouti, resigned, kenya, meridians,
# Nearest to this: which, that, the, it, agouti, a, archaeopteryx, one,
# Nearest to states: sebastian, dasyprocta, acacia, centralization, agouti, canaris, recitative, paradox,
# Nearest to five: four, six, eight, three, seven, zero, nine, two,
# Nearest to people: sci, alabama, shooter, phi, caribbean, arabic, queues, slope,
# Nearest to by: was, with, dasyprocta, from, altenberg, eight, in, six,
# Nearest to known: pe, openings, deflation, elapsed, linux, refrigeration, warp, frying,
# Nearest to if: but, bothnian, nasal, canova, archie, akh, dasyprocta, finite,
# Average loss at step  42000 :  5.379744501113891
# Average loss at step  44000 :  5.250735148906708
# Average loss at step  46000 :  5.2696339032649995
# Average loss at step  48000 :  5.213016191601754
# Average loss at step  50000 :  4.983438088774681
# Nearest to all: automatic, three, two, dasyprocta, spotters, visibly, four, osteoblasts,
# Nearest to united: adnan, kasparov, circ, matilda, of, ace, option, hadith,
# Nearest to used: agouti, found, circ, gibeon, pronounced, laura, trusts, relied,
# Nearest to however: but, keto, agouti, circ, when, that, which, like,
# Nearest to their: his, its, the, her, predicates, a, shout, wallace,
# Nearest to not: still, also, phi, it, to, prior, they, poem,
# Nearest to some: many, these, appeared, robeson, the, dasyprocta, agouti, other,
# Nearest to th: eight, six, connery, nine, deck, seven, four, akkad,
# Nearest to about: kapoor, dasyprocta, archie, deepening, six, thuringiensis, agouti, nearest,
# Nearest to this: which, it, the, that, archaeopteryx, a, backgammon, agouti,
# Nearest to states: sebastian, dasyprocta, acacia, centralization, agouti, zorro, canaris, recitative,
# Nearest to five: four, six, three, eight, seven, two, zero, agouti,
# Nearest to people: sci, phi, alabama, shooter, caribbean, arabic, kapoor, queues,
# Nearest to by: with, was, from, dasyprocta, in, as, for, six,
# Nearest to known: pe, openings, used, deflation, linux, elapsed, warp, macgregor,
# Nearest to if: but, bothnian, nasal, canova, and, akh, archie, dasyprocta,
# Average loss at step  52000 :  5.037900343537331
# Average loss at step  54000 :  5.196579113125801
# Average loss at step  56000 :  5.036053262591362
# Average loss at step  58000 :  5.077579394578934
# Average loss at step  60000 :  4.930865727424622
# Nearest to all: two, three, automatic, any, ursus, anchor, dasyprocta, spotters,
# Nearest to united: adnan, circ, kasparov, matilda, of, ace, pulau, vulgar,
# Nearest to used: agouti, found, gibeon, circ, pulau, pronounced, laura, known,
# Nearest to however: but, ursus, agouti, when, keto, circ, which, that,
# Nearest to their: its, his, the, her, predicates, some, them, circ,
# Nearest to not: still, also, it, they, poem, to, phi, prior,
# Nearest to some: many, these, other, both, the, appeared, robeson, dasyprocta,
# Nearest to th: six, eight, four, nine, five, connery, zero, deck,
# Nearest to about: six, dasyprocta, archie, kapoor, deepening, five, quadratic, four,
# Nearest to this: which, it, that, the, one, ursus, agouti, there,
# Nearest to states: sebastian, dasyprocta, acacia, agouti, centralization, recitative, canaris, zorro,
# Nearest to five: six, four, eight, three, seven, nine, zero, two,
# Nearest to people: sci, shooter, alabama, phi, two, ursus, arabic, kapoor,
# Nearest to by: was, with, dasyprocta, be, eight, from, as, altenberg,
# Nearest to known: pe, openings, used, ursus, linux, deflation, seen, warp,
# Nearest to if: but, when, bothnian, akh, archie, dasyprocta, canova, nasal,
# Average loss at step  62000 :  5.006639894366264
# Average loss at step  64000 :  4.825194416999817
# Average loss at step  66000 :  4.5919782756567
# Average loss at step  68000 :  4.990301493406296
# Average loss at step  70000 :  4.894904788613319
# Nearest to all: automatic, two, any, three, several, ursus, anchor, dasyprocta,
# Nearest to united: adnan, of, circ, matilda, kasparov, scanner, ace, pulau,
# Nearest to used: found, agouti, clo, circ, gibeon, known, callithrix, thaler,
# Nearest to however: but, when, ursus, that, agouti, which, circ, keto,
# Nearest to their: its, his, the, her, predicates, some, them, shout,
# Nearest to not: still, also, they, to, callithrix, poem, it, usually,
# Nearest to some: many, these, other, their, the, its, both, agouti,
# Nearest to th: six, eight, nine, connery, five, four, seven, deck,
# Nearest to about: dasyprocta, six, archie, kapoor, callithrix, deepening, quadratic, five,
# Nearest to this: which, it, the, that, agouti, one, backgammon, there,
# Nearest to states: sebastian, dasyprocta, acacia, centralization, zorro, callithrix, agouti, recitative,
# Nearest to five: six, four, eight, three, seven, zero, nine, two,
# Nearest to people: sci, shooter, alabama, phi, thaler, ursus, microcebus, kapoor,
# Nearest to by: was, with, be, microcebus, dasyprocta, milne, from, altenberg,
# Nearest to known: used, pe, openings, ursus, thaler, seen, well, jhanas,
# Nearest to if: when, but, bothnian, is, akh, archie, did, canova,
# Average loss at step  72000 :  4.755194232821465
# Average loss at step  74000 :  4.800472438573837
# Average loss at step  76000 :  4.714367124080658
# Average loss at step  78000 :  4.79567025989294
# Average loss at step  80000 :  4.802121495127678
# Nearest to all: two, automatic, several, some, any, ursus, dasyprocta, many,
# Nearest to united: adnan, scanner, kasparov, circ, matilda, vulgar, ace, of,
# Nearest to used: found, agouti, known, clo, gibeon, circ, callithrix, referred,
# Nearest to however: but, when, that, ursus, agouti, circ, which, keto,
# Nearest to their: its, his, her, the, predicates, some, shout, responsibility,
# Nearest to not: still, they, also, to, it, usually, poem, you,
# Nearest to some: many, these, both, several, other, their, its, most,
# Nearest to th: six, eight, five, nine, seven, connery, akkad, robb,
# Nearest to about: dasyprocta, six, deepening, archie, that, callithrix, kapoor, quadratic,
# Nearest to this: which, it, that, the, there, backgammon, ursus, agouti,
# Nearest to states: sebastian, acacia, dasyprocta, zorro, agouti, callithrix, recitative, centralization,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to people: sci, shooter, phi, alabama, thaler, ursus, foss, kapoor,
# Nearest to by: was, microcebus, with, dasyprocta, be, milne, when, from,
# Nearest to known: used, pe, seen, openings, such, ursus, thaler, well,
# Nearest to if: when, but, bothnian, where, akh, gigantopithecus, canova, for,
# Average loss at step  82000 :  4.770704249978065
# Average loss at step  84000 :  4.7451841967105866
# Average loss at step  86000 :  4.762125992059707
# Average loss at step  88000 :  4.736591826319694
# Average loss at step  90000 :  4.7394775295257565
# Nearest to all: two, several, automatic, both, ursus, however, some, any,
# Nearest to united: adnan, of, scanner, circ, matilda, kasparov, vulgar, ace,
# Nearest to used: found, known, agouti, clo, gibeon, thaler, circ, referred,
# Nearest to however: but, that, ursus, when, agouti, which, circ, although,
# Nearest to their: its, his, the, her, them, predicates, responsibility, shout,
# Nearest to not: still, they, also, usually, it, poem, never, callithrix,
# Nearest to some: many, these, several, both, other, their, the, most,
# Nearest to th: six, eight, nine, seven, zero, connery, five, robb,
# Nearest to about: dasyprocta, archie, deepening, callithrix, six, that, kapoor, rarities,
# Nearest to this: which, it, the, that, one, a, ursus, barberini,
# Nearest to states: acacia, sebastian, dasyprocta, zorro, centralization, callithrix, agouti, recitative,
# Nearest to five: seven, four, eight, six, three, zero, nine, two,
# Nearest to people: sci, shooter, phi, alabama, thaler, ursus, microcebus, callithrix,
# Nearest to by: was, when, with, microcebus, dasyprocta, be, as, in,
# Nearest to known: used, seen, pe, such, openings, available, ursus, thaler,
# Nearest to if: when, where, bothnian, but, gigantopithecus, did, akh, archie,
# Average loss at step  92000 :  4.675438236236572
# Average loss at step  94000 :  4.721628774642944
# Average loss at step  96000 :  4.6969899557828905
# Average loss at step  98000 :  4.59450326359272
# Average loss at step  100000 :  4.7019286875724795
# Nearest to all: many, several, some, both, automatic, ursus, any, two,
# Nearest to united: adnan, scanner, matilda, circ, kasparov, vulgar, dioscorus, ace,
# Nearest to used: known, found, agouti, referred, clo, gibeon, thaler, circ,
# Nearest to however: but, that, when, ursus, although, which, agouti, circ,
# Nearest to their: its, his, her, the, some, them, responsibility, predicates,
# Nearest to not: still, they, also, usually, you, callithrix, poem, never,
# Nearest to some: many, these, several, the, both, their, all, other,
# Nearest to th: six, nine, seven, eight, connery, etudes, five, akkad,
# Nearest to about: dasyprocta, six, deepening, archie, that, obscure, callithrix, kapoor,
# Nearest to this: which, it, the, that, ursus, there, agouti, archaeopteryx,
# Nearest to states: acacia, dasyprocta, sebastian, zorro, agouti, centralization, mctaggart, callithrix,
# Nearest to five: four, seven, eight, three, six, zero, two, nine,
# Nearest to people: sci, shooter, thaler, phi, alabama, ursus, microcebus, bottlenose,
# Nearest to by: microcebus, with, was, dasyprocta, when, be, as, eight,
# Nearest to known: used, such, seen, available, pe, thaler, openings, ursus,
# Nearest to if: when, where, gigantopithecus, bothnian, but, akh, dasyprocta, archie,
